# %%
unicode_0 = chr(0)
unicode_0
# Out:
# '\x00'

# %%
unicode_0.__repr__()
# Out:
# "'\\x00'"

# %% [markdown]
# ## Why is it wrong?

# %%
def decode_utf8_bytes_to_str_wrong(bytestring: bytes):
    return "".join([bytes([b]).decode("utf-8") for b in bytestring])

# %%
## Wrong because one should decode the whole byte, but not individually.

# %% [markdown]
# ## BPE Training on TinyStories
#
# Train a byte-level BPE tokenizer on the TinyStories dataset with vocab_size=10,000 and the `<|endoftext|>` special token. Measure time, memory, and find the longest token.

# %%
# train on the tinystories
# uv run python -m cProfile -s cumulative train_bpe_tinystories.py

# %%
# TODO: train on the openweb data
